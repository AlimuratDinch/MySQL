# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
df = pd.read_excel('test.xlsx', sheet_name='DA', header=0)

# %%
df.head()
# Out:
#        ANNEE                    NOM_MILIEU  \
# 0  2022-2023                           NaN
# 1  2022-2023             Jules-Verne (055)
# 2  2022-2023             Jules-Verne (055)
# 3  2022-2023  Sainte-Germaine-Cousin (002)
# 4  2022-2023  Sainte-Germaine-Cousin (002)
#
#                                       ENJEU_PRINCIP  \
# 0                                               NaN
# 1                              Réussite en français
# 2  Préscolaire - Mise en œuvre du nouveau programme
# 3                                       Code de vie
# 4                Bien-être psychologique des élèves
#
#                                  ACCOMPGN  PREC  \
# 0                                     NaN   NaN
# 1  Poursuite d'un accompagnement existant   NaN
# 2           Nouvel accompagnement demandé   NaN
# 3  Poursuite d'un accompagnement existant   NaN
# 4           Nouvel accompagnement demandé   NaN
#
#                                                 LIEN  \
# ...

# %%
df.to_csv('Demandes_Accompagnement.csv', index=False)
