# %%
from PIL import Image
import os

# %%
img1 = Image.open("image1.png")
img2 = Image.open("image2.png")
print(img1)
print(img2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=225x225 at 0x1A51ADD1940>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=225x225 at 0x1A51ADA3800>

# %%
folder_path = "C:\\Users\\a-dinchdonmez\\Desktop\\Machine Learning\\project"
folder_path = "."
folder_path
# Out:
# '.'

# %%
files = os.listdir(folder_path)
files
# Out:
# ['image1.png', 'image2.png', 'image3.png', 'test.ipynb']

# %%
image_files = [file for file in files if file.endswith(".png")]

# %%
images = [Image.open(os.path.join(folder_path, img)) for img in image_files]
images[2]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=225x225>

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=225x225>

# %%
import numpy as np

# %%
array = np.array(img1)
array.shape
# Out:
# (225, 225, 3)

# %%
array[:1]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img3 = Image.open("angry_100.jpg")
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=48x48>

# %%
array = np.array(img3)
array
# Out:
# array([[104,  84,  74, ...,  45,  45,  45],
#        [103,  84,  71, ...,  46,  45,  45],
#        [ 95,  84,  69, ...,  46,  45,  44],
#        ...,
#        [ 71,  65,  62, ...,  61,  52,  43],
#        [ 66,  59,  58, ...,  59,  55,  46],
#        [ 68,  85,  89, ...,  56,  57,  51]], dtype=uint8)

# %%
array.shape
# Out:
# (48, 48)

# %%
array[:5]
# Out:
# array([[104,  84,  74,  62,  56,  55,  55,  45,  37,  93, 118, 127, 127,
#         125, 122, 124, 130, 135, 137, 153, 157, 184, 219, 217, 200, 156,
#         146, 134, 133, 127, 104,  49,  30,  39,  33,  39,  42,  45,  50,
#          51,  52,  51,  50,  48,  46,  45,  45,  45],
#        [103,  84,  71,  61,  56,  54,  40,  29,  85, 118, 125, 122, 117,
#         122, 125, 122, 128, 135, 139, 156, 180, 207, 209, 184, 173, 146,
#         145, 136, 129, 121, 119, 104,  54,  25,  36,  36,  42,  45,  51,
#          54,  53,  52,  50,  48,  47,  46,  45,  45],
#        [ 95,  84,  69,  60,  55,  45,  26,  76, 124, 123, 118, 123, 121,
#         120, 124, 122, 127, 128, 139, 157, 171, 163, 150, 145, 143, 140,
#         140, 127, 117, 111, 112, 111,  97,  50,  34,  39,  41,  48,  49,
#          54,  53,  51,  49,  48,  47,  46,  45,  44],
#        [ 92,  80,  70,  47,  38,  34,  64, 117, 120, 119, 115, 119, 122,
#         125, 127, 122, 125, 128, 124, 112, 115, 117, 122, 122, 135, 141,
# ...
